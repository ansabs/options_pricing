# %% [markdown]
# # Local Volatility Model vs. Black-Scholes Forecasting Using Real Nvidia Market Data

# %% [markdown]
# intro/description sim 5 random strikes

# %%
# imports
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf
import datetime
import multiprocessing
from sklearn import metrics
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF
from sklearn.model_selection import train_test_split
from scipy.stats import norm
from scipy.interpolate import RegularGridInterpolator
from joblib import Parallel, delayed

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### NVDA Options Data

# %%
# get NVDA options data
ticker = yf.Ticker("NVDA")
options_list = []
exps = ticker.options  # expiration dates

for e in exps:
    opt = ticker.option_chain(e)
    opt_df = pd.concat([opt.calls, opt.puts])
    opt_df["expirationDate"] = pd.to_datetime(e)
    options_list.append(opt_df)

# combine all options into one DataFrame
options = pd.concat(options_list, ignore_index=True)

# days until expiration
today = datetime.datetime.today()
options["dte"] = (options["expirationDate"] - today).dt.days / 365
options['T'] = options['dte'] / 365 # years until expiration (T)

# IV
options["impliedVolatility"] = options["impliedVolatility"].replace(0, np.nan)
options = options.dropna(subset=["impliedVolatility"])

# call/put labels
options["option_type"] = options["contractSymbol"].apply(
    lambda x: "Call" if "C" in x else "Put"
)
call = options[options['option_type'] == 'Call']
put = options[options['option_type'] == 'Put']

# display
options
# Out:
#            contractSymbol             lastTradeDate  strike  lastPrice  \
# 0     NVDA250207C00050000 2025-01-31 18:27:27+00:00    50.0      74.15
# 1     NVDA250207C00055000 2025-01-31 19:36:19+00:00    55.0      67.80
# 2     NVDA250207C00060000 2025-01-31 20:57:27+00:00    60.0      59.98
# 3     NVDA250207C00065000 2025-01-31 15:34:04+00:00    65.0      61.35
# 4     NVDA250207C00070000 2025-01-31 18:56:23+00:00    70.0      50.80
# ...                   ...                       ...     ...        ...
# 7354  NVDA270115P00260000 2025-01-30 20:25:21+00:00   260.0     138.25
# 7355  NVDA270115P00270000 2025-01-17 17:44:04+00:00   270.0     133.97
# 7356  NVDA270115P00280000 2025-01-23 17:05:08+00:00   280.0     136.50
# 7357  NVDA270115P00290000 2025-01-31 14:41:58+00:00   290.0     165.43
# 7358  NVDA270115P00300000 2025-01-31 15:55:29+00:00   300.0     173.29
#
#          bid     ask    change  percentChange  volume  openInterest  \
# 0      68.85   70.90  3.560005       5.043215     4.0          83.0
# 1      63.85   65.90  1.639999       2.478838    18.0          38.0
# 2      59.10   60.70 -1.860001      -3.007763   113.0         120.0
# 3      53.90   55.95 -0.480003      -0.776328     2.0           7.0
# 4      48.40   50.75 -1.700001      -3.238097   140.0         510.0
# ...      ...     ...       ...            ...     ...           ...
# 7354  139.55  146.00  0.000000       0.000000    50.0         237.0
# 7355  148.95  152.15  0.000000       0.000000     2.0          59.0
# 7356  157.75  166.00  0.000000       0.000000    30.0          60.0
# 7357  167.35  175.00 -3.400009      -2.013866     1.0         117.0
# 7358  177.05  185.00 -5.260010      -2.945959     9.0          64.0
#
#       impliedVolatility  inTheMoney contractSize currency expirationDate  \
# 0              3.835938        True      REGULAR      USD     2025-02-07
# 1              3.462892        True      REGULAR      USD     2025-02-07
# 2              2.953128        True      REGULAR      USD     2025-02-07
# 3              2.843753        True      REGULAR      USD     2025-02-07
# 4              2.412113        True      REGULAR      USD     2025-02-07
# ...                 ...         ...          ...      ...            ...
# 7354           0.459325        True      REGULAR      USD     2027-01-15
# 7355           0.369391        True      REGULAR      USD     2027-01-15
# 7356           0.486089        True      REGULAR      USD     2027-01-15
# 7357           0.474981        True      REGULAR      USD     2027-01-15
# 7358           0.486669        True      REGULAR      USD     2027-01-15
#
#            dte         T option_type
# 0     0.016438  0.000045        Call
# 1     0.016438  0.000045        Call
# 2     0.016438  0.000045        Call
# 3     0.016438  0.000045        Call
# 4     0.016438  0.000045        Call
# ...        ...       ...         ...
# 7354  1.953425  0.005352         Put
# 7355  1.953425  0.005352         Put
# 7356  1.953425  0.005352         Put
# 7357  1.953425  0.005352         Put
# 7358  1.953425  0.005352         Put
#
# [6169 rows x 18 columns]

# %%
# pick 5 random strikes to simulate
selected_strikes = call["strike"].sample(10, random_state=26).values  
print("Selected Strikes:", selected_strikes)
# Out:
# Selected Strikes: [  90.   98.  131.   10.   95.  250. 2150.   28.  140. 2350.]

# %% [markdown]
# ### NVDA Stock Data

# %% [markdown]
# As of January 31st, 2025, NVDA stock price is: $120.07

# %%
today_price = ticker.history(period="1d")["Close"].iloc[-1]  
stock = ticker.history()
print(f"Current NVDA Price: ${today_price.round(2)}")
stock
# Out:
# Current NVDA Price: $120.07
#                                  Open        High         Low       Close  \
# Date
# 2025-01-02 00:00:00-05:00  136.000000  138.880005  134.630005  138.309998
# 2025-01-03 00:00:00-05:00  140.009995  144.899994  139.729996  144.470001
# 2025-01-06 00:00:00-05:00  148.589996  152.160004  147.820007  149.429993
# 2025-01-07 00:00:00-05:00  153.029999  153.130005  140.009995  140.139999
# 2025-01-08 00:00:00-05:00  142.580002  143.949997  137.559998  140.110001
# 2025-01-10 00:00:00-05:00  137.449997  139.919998  134.220001  135.910004
# 2025-01-13 00:00:00-05:00  129.990005  133.490005  129.509995  133.229996
# 2025-01-14 00:00:00-05:00  136.050003  136.380005  130.050003  131.759995
# 2025-01-15 00:00:00-05:00  133.649994  136.449997  131.289993  136.240005
# 2025-01-16 00:00:00-05:00  138.639999  138.750000  133.490005  133.570007
# 2025-01-17 00:00:00-05:00  136.690002  138.500000  135.460007  137.710007
# 2025-01-21 00:00:00-05:00  139.160004  141.830002  137.089996  140.830002
# 2025-01-22 00:00:00-05:00  144.660004  147.789993  143.669998  147.070007
# 2025-01-23 00:00:00-05:00  145.050003  147.229996  143.720001  147.220001
# 2025-01-24 00:00:00-05:00  148.369995  148.970001  141.880005  142.619995
# 2025-01-27 00:00:00-05:00  124.800003  128.399994  116.699997  118.419998
# 2025-01-28 00:00:00-05:00  121.809998  129.000000  116.250000  128.990005
# 2025-01-29 00:00:00-05:00  126.500000  126.889999  120.050003  123.699997
# 2025-01-30 00:00:00-05:00  123.099998  125.000000  118.099998  124.650002
# 2025-01-31 00:00:00-05:00  123.809998  127.849998  119.190002  120.070000
#
#                               Volume  Dividends  Stock Splits
# Date
# 2025-01-02 00:00:00-05:00  198247200        0.0           0.0
# 2025-01-03 00:00:00-05:00  229322500        0.0           0.0
# 2025-01-06 00:00:00-05:00  265377400        0.0           0.0
# 2025-01-07 00:00:00-05:00  351782200        0.0           0.0
# 2025-01-08 00:00:00-05:00  227349900        0.0           0.0
# 2025-01-10 00:00:00-05:00  207602500        0.0           0.0
# 2025-01-13 00:00:00-05:00  204808900        0.0           0.0
# 2025-01-14 00:00:00-05:00  195590500        0.0           0.0
# 2025-01-15 00:00:00-05:00  185217300        0.0           0.0
# 2025-01-16 00:00:00-05:00  209235600        0.0           0.0
# 2025-01-17 00:00:00-05:00  201188800        0.0           0.0
# 2025-01-21 00:00:00-05:00  197749000        0.0           0.0
# 2025-01-22 00:00:00-05:00  237651400        0.0           0.0
# 2025-01-23 00:00:00-05:00  155915500        0.0           0.0
# 2025-01-24 00:00:00-05:00  234657600        0.0           0.0
# 2025-01-27 00:00:00-05:00  818830900        0.0           0.0
# 2025-01-28 00:00:00-05:00  579666400        0.0           0.0
# 2025-01-29 00:00:00-05:00  467120600        0.0           0.0
# 2025-01-30 00:00:00-05:00  392925500        0.0           0.0
# 2025-01-31 00:00:00-05:00  385199825        0.0           0.0

# %% [markdown]
# ## Implied Volatility Surface

# %%
# calls
K, T, iv = call['strike'],  call['T'], call['impliedVolatility']
fig = plt.figure(figsize=(16,9))
ax = plt.axes(projection='3d')
surf = ax.plot_trisurf(K, T, iv, cmap='coolwarm',
                       linewidth=0.1, antialiased=True)

# labels and title
ax.set_xlabel('Strike Price (K)')
ax.set_ylabel('Time to Expiration (T)')
ax.set_zlabel('Implied Volatility (IV)')
ax.set_title('Implied Volatility Surface (Calls)')

plt.show()

# %%
# puts
K, T, iv = put['strike'],  put['T'], put['impliedVolatility']
fig = plt.figure(figsize=(16,9))
ax = plt.axes(projection='3d')
surf = ax.plot_trisurf(K, T, iv, cmap='coolwarm',
                       linewidth=0.1, antialiased=True)

# labels and title
ax.set_xlabel('Strike Price (K)')
ax.set_ylabel('Time to Expiration (T)')
ax.set_zlabel('Implied Volatility (IV)')
ax.set_title('Implied Volatility Surface (Puts)')

plt.show()

# %% [markdown]
# ## Local Volatility Surface

# %% [markdown]
# add Dupire’s equation in LaTex

# %%
# Initialize C using Black-Scholes
def black_scholes(S, K, T, r, sigma, type='call'):
    d1 = (np.log(S / K) + (r + 0.5 * sigma**2) * T) / (sigma * np.sqrt(T))
    d2 = d1 - sigma * np.sqrt(T)
    if type == 'call':
        return S * norm.cdf(d1) - K * np.exp(-r * T) * norm.cdf(d2)
    if type == 'put':
        return - S * norm.cdf(-d1) + K * np.exp(-r * T) * norm.cdf(-d2)

# Parameters
steps = 100
S0 = 100     # Spot price
K_min, K_max = 50, 150  # Strike price range
T_min, T_max = 0, 2  # Time to maturity range (2 years)
r = 0.05    # Risk-free rate
sigma = 0.2 # Volatility
dT = (K_max - K_min) / steps
dK = (T_max - T_min) / steps

# %%
# Solve For Partial Derivatives Using Finite Difference Method
def fd_solve_diff(K_min, K_max, T_min, T_max, r, S0, steps, dT, dK):
    # construct domain grid
    num_K = steps
    num_T = steps
    K_vals = np.linspace(K_min, K_max, num_K)
    T_vals = np.linspace(T_min, T_max, num_K)

    # initialize C
    C = np.zeros((num_K, num_T))
    for i, K in enumerate(K_vals):
        for j, T in enumerate(T_vals):
            C[i, j] = black_scholes(S0, K, T, r, sigma)

    # Solve for dC/dK
    dC_dK = np.zeros_like(C)
    for i in range(1, num_K - 1):
        for j in range(num_T):
            dC_dK[i, j] = (C[i+1, j] - C[i-1, j]) / (2 * dK) 

    # Solve for dC/dt
    dC_dT = np.zeros_like(C)
    for i in range(num_K):
         for j in range(1, num_T - 1):
            dC_dT[i, j] = (C[i, j+1] - C[i, j-1]) / (2 * dT)

    # Solve for d2C_dK2 (2nd Derivative)
    dC_dK2 = np.zeros_like(C)
    for i in range(1, num_K - 1):
         for j in range(num_T):
            dC_dK2[i, j] = (C[i+1, j] - 2 * C[i, j] - C[i-1, j]) / (2 * dT)

    return C, K_vals, T_vals, dC_dK, dC_dT, dC_dK2

# %%
C, K_vals, T_vals, dC_dK, dC_dT, dC_dK2 = fd_solve_diff(K_min, K_max, T_min, T_max, r, S0, steps, dT, dK)
# Out:
# /var/folders/_d/f835sqm57dz2nyvw8sbgld300000gn/T/ipykernel_88373/2355004363.py:3: RuntimeWarning: divide by zero encountered in scalar divide
#   d1 = (np.log(S / K) + (r + 0.5 * sigma**2) * T) / (sigma * np.sqrt(T))

# %%
# Input Values into Dupire’s equation
sigma_local = np.zeros_like(C)
for i, K in enumerate(K_vals):  
    for j, T in enumerate(T_vals):
        denom = 0.5 * (K**2) * dC_dK2[i, j]
        if abs(denom) < 1e-10:
            sigma_local[i, j] = np.nan  # set to 0
            continue

        num = dC_dT[i, j] + r * K * dC_dK[i, j]
        sigma_local[i, j] = np.sqrt(max(num / denom, 0))

# %%
# plot results
K_vals_mesh, T_vals_mesh = np.meshgrid(K_vals, T_vals)

fig = plt.figure(figsize=(16,10))
ax = plt.axes(projection='3d')



surf = ax.plot_trisurf(K_vals_mesh.ravel(), T_vals_mesh.ravel(), sigma_local.ravel(), cmap='coolwarm',
                       linewidth=0.1, antialiased=True)

# labels and title
ax.set_xlabel('Strike Price (K)')
ax.set_ylabel('Time to Expiration (T)')
ax.set_zlabel('Local Volatility (LV)')
ax.set_title('Local Volatility Surface (Calls)')

plt.show()
# Out:
# /Users/ansa/opt/anaconda3/lib/python3.10/site-packages/matplotlib/tri/_triangulation.py:181: RuntimeWarning: invalid value encountered in cast
#   triangles = np.asarray(triangles, dtype=np.int32)

# %% [markdown]
# ## Monte Carlo Simulations: Local Volatility and Black-Scholes (Call Options)

# %% [markdown]
# Approach: run monte carlo sim for initial conditions of NVDA options

# %%
call
# Out:
#            contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0     NVDA250207C00050000 2025-01-31 18:27:27+00:00    50.0      74.15  68.85
# 1     NVDA250207C00055000 2025-01-31 19:36:19+00:00    55.0      67.80  63.85
# 2     NVDA250207C00060000 2025-01-31 20:57:27+00:00    60.0      59.98  59.10
# 3     NVDA250207C00065000 2025-01-31 15:34:04+00:00    65.0      61.35  53.90
# 4     NVDA250207C00070000 2025-01-31 18:56:23+00:00    70.0      50.80  48.40
# ...                   ...                       ...     ...        ...    ...
# 7304  NVDA270115C00260000 2025-01-31 20:58:03+00:00   260.0      11.80  11.50
# 7305  NVDA270115C00270000 2025-01-31 19:18:06+00:00   270.0      11.57  10.70
# 7306  NVDA270115C00280000 2025-01-31 20:48:18+00:00   280.0      10.20  10.00
# 7307  NVDA270115C00290000 2025-01-31 20:49:41+00:00   290.0       9.50   9.40
# 7308  NVDA270115C00300000 2025-01-31 20:59:25+00:00   300.0       8.85   8.75
#
#         ask    change  percentChange  volume  openInterest  impliedVolatility  \
# 0     70.90  3.560005       5.043215     4.0          83.0           3.835938
# 1     65.90  1.639999       2.478838    18.0          38.0           3.462892
# 2     60.70 -1.860001      -3.007763   113.0         120.0           2.953128
# 3     55.95 -0.480003      -0.776328     2.0           7.0           2.843753
# 4     50.75 -1.700001      -3.238097   140.0         510.0           2.412113
# ...     ...       ...            ...     ...           ...                ...
# 7304  11.95 -0.349999      -2.880654   239.0        2639.0           0.567936
# 7305  11.10  0.150000       1.313482     8.0        1309.0           0.567784
# 7306  10.35 -0.800000      -7.272728    13.0        1580.0           0.568242
# 7307   9.75 -0.690000      -6.771340    66.0       12348.0           0.569951
# 7308   9.10 -0.849999      -8.762880  2214.0       29391.0           0.569645
#
#       inTheMoney contractSize currency expirationDate       dte         T  \
# 0           True      REGULAR      USD     2025-02-07  0.016438  0.000045
# 1           True      REGULAR      USD     2025-02-07  0.016438  0.000045
# 2           True      REGULAR      USD     2025-02-07  0.016438  0.000045
# 3           True      REGULAR      USD     2025-02-07  0.016438  0.000045
# 4           True      REGULAR      USD     2025-02-07  0.016438  0.000045
# ...          ...          ...      ...            ...       ...       ...
# 7304       False      REGULAR      USD     2027-01-15  1.953425  0.005352
# 7305       False      REGULAR      USD     2027-01-15  1.953425  0.005352
# 7306       False      REGULAR      USD     2027-01-15  1.953425  0.005352
# 7307       False      REGULAR      USD     2027-01-15  1.953425  0.005352
# 7308       False      REGULAR      USD     2027-01-15  1.953425  0.005352
#
#      option_type
# 0           Call
# 1           Call
# 2           Call
# 3           Call
# 4           Call
# ...          ...
# 7304        Call
# 7305        Call
# 7306        Call
# 7307        Call
# 7308        Call
#
# [2652 rows x 18 columns]

# %% [markdown]
# ### Local Volatility

# %%
# new ranges for prediction purposes
K_min, K_max = 0, 3000  
T_min, T_max = 0, 0.5 

dt = 1/365        # 1 day step size
steps = int(T // dt)
r = 0.05
interp_sigma = RegularGridInterpolator((K_vals, T_vals), sigma_local, bounds_error=True, fill_value=0)
call_sample = call[call['strike'].isin(selected_strikes)].drop_duplicates(subset='strike')
call_sample
# Out:
#            contractSymbol             lastTradeDate  strike  lastPrice  \
# 8     NVDA250207C00090000 2025-01-31 20:52:42+00:00    90.0      30.20
# 9     NVDA250207C00095000 2025-01-31 20:55:02+00:00    95.0      25.55
# 24    NVDA250207C00131000 2025-01-31 20:59:55+00:00   131.0       1.20
# 33    NVDA250207C00140000 2025-01-31 20:59:59+00:00   140.0       0.41
# 68    NVDA250207C00250000 2025-01-31 19:51:47+00:00   250.0       0.01
# 284   NVDA250221C00028000 2025-01-31 14:30:08+00:00    28.0      94.66
# 374   NVDA250221C00098000 2025-01-31 17:13:56+00:00    98.0      27.80
# 697   NVDA250221C02150000 2024-06-07 17:16:36+00:00  2150.0      30.59
# 711   NVDA250221C02350000 2024-06-06 18:25:54+00:00  2350.0      19.88
# 1324  NVDA250321C00010000 2025-01-30 16:01:40+00:00    10.0     108.75
#
#          bid     ask     change  percentChange   volume  openInterest  \
# 8      29.25   31.60  -3.099998      -9.309305    203.0         653.0
# 9      24.05   26.30  -3.000000     -10.507881     80.0         588.0
# 24      1.19    1.23  -1.070000     -47.136562  75396.0        6540.0
# 33      0.40    0.41  -0.280000     -40.579712  80178.0       33387.0
# 68      0.00    0.01   0.000000       0.000000  28882.0         129.0
# 284    90.00   93.40  -4.839996      -4.864318     80.0         158.0
# 374    22.10   23.80   1.599999       6.106865     84.0        1535.0
# 697    27.75   28.85   3.590000      13.296300      1.0          10.0
# 711    19.00   20.05  19.880000            NaN      NaN           2.0
# 1324  107.60  111.40   0.000000       0.000000      2.0         306.0
#
#       impliedVolatility  inTheMoney contractSize currency expirationDate  \
# 8              1.248051        True      REGULAR      USD     2025-02-07
# 9              0.843752        True      REGULAR      USD     2025-02-07
# 24             0.697269       False      REGULAR      USD     2025-02-07
# 33             0.746096       False      REGULAR      USD     2025-02-07
# 68             1.625002       False      REGULAR      USD     2025-02-07
# 284            3.927735        True      REGULAR      USD     2025-02-21
# 374            0.675296        True      REGULAR      USD     2025-02-21
# 697            8.756840       False      REGULAR      USD     2025-02-21
# 711            8.043706       False      REGULAR      USD     2025-02-21
# 1324           4.535161        True      REGULAR      USD     2025-03-21
#
#            dte         T option_type
# 8     0.016438  0.000045        Call
# 9     0.016438  0.000045        Call
# 24    0.016438  0.000045        Call
# 33    0.016438  0.000045        Call
# 68    0.016438  0.000045        Call
# 284   0.054795  0.000150        Call
# 374   0.054795  0.000150        Call
# 697   0.054795  0.000150        Call
# 711   0.054795  0.000150        Call
# 1324  0.131507  0.000360        Call

# %%
def mc_sim(steps, S0, r, K, T, dt, chunk_size):
    S = np.zeros((chunk_size, steps + 1))
    S[:, 0] = S0
    np.random.seed()

    for t in range(1, steps + 1):
        # clip for proper domain
        K_interp = np.clip(S[:, t-1], K_vals.min(), K_vals.max())
        T_remaining = T - (t-1)*dt
        # clip for proper domain
        T_remaining = np.clip(T_remaining, T_vals.min(), T_vals.max())
        # interpolate sigma
        sigma = interp_sigma(np.vstack((K_interp, np.full_like(K_interp, T_remaining))).T)
        # replace nans with mean
        sigma = np.nan_to_num(sigma, nan=np.mean(sigma[~np.isnan(sigma)]))

        # Euler-Maruyama step
        Z = np.random.randn(chunk_size)
        drift = (r - 0.5 * sigma**2) * dt
        diffusion = sigma * np.sqrt(dt) * Z
        S[:, t] = S[:, t-1] * np.exp(drift + diffusion)
    
    return S

# %%
def nvda_sim(data=call_sample, num_sims=10000):
    
    num_cores = multiprocessing.cpu_count()
    chunk_size = num_sims // num_cores
    simulated_prices = []
    strikes = []
    symbols = []
    for index, row in data.iterrows():
        
        # set inital condtions based on NVDA data
        #S = np.zeros((chunk_size, steps + 1))
        stock.index = stock.index.tz_localize(None)

        # Set S0 using stock price from 2 years ago
        start_date = pd.to_datetime('today')
        #start_price = stock.loc[stock.index == start_date, 'Close'].iloc[0]
        #closest_date = stock.iloc[(nvda_prices['Date'] - start_date).abs().argmin()]
        #start_price = closest_date['Close']
        #date_diff = abs(stock.index - start_date)
        #closest_date_index = np.argmin(date_diff)

        #closest_date = stock.index[closest_date_index]
        #start_price = stock.loc[closest_date, 'Close']

        S0 = today_price 

        #S[:, 0] = S0
        symbol = row['contractSymbol'] # contract symbol
        K = row['strike']
        T = (pd.to_datetime(row['expirationDate']) - pd.to_datetime('today')).days / 365  # time to expiration in years
        #K_interp = np.clip(S[:, t-1], K_vals.min(), K_vals.max())
        #sigma = interp_sigma(np.vstack((K_interp, np.full_like(K_interp, T_remaining))).T)
        
        # Run Monte Carlo Simulation

        #S_list = mc_sim2(steps, S0, r, K, T, dt, chunk_size, sigma)

        S_list = Parallel(n_jobs=num_cores)(
            delayed(mc_sim)(steps, S0, r, K, T, dt, chunk_size) 
            for _ in range(num_cores)
        )
        S_array = np.concatenate(S_list, axis=0)
        
        # Compute simulated payoff
        sim_payoff = np.maximum(S_array[:, -1] - K, 0)
        sim_call_price = np.exp(-r * T) * np.mean(sim_payoff)
        simulated_prices.append(sim_call_price)
        strikes.append(K)
        symbols.append(symbol)
    predictions = pd.DataFrame({
        'Contract Symbol': symbols,
        'Strike': strikes,
        'Simulated Price': simulated_prices
    })
    return predictions

# %%
# %%time
predictions = nvda_sim()
predictions
# Out:
# /Users/ansa/opt/anaconda3/lib/python3.10/site-packages/numpy/_core/fromnumeric.py:3904: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/ansa/opt/anaconda3/lib/python3.10/site-packages/numpy/_core/_methods.py:147: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /Users/ansa/opt/anaconda3/lib/python3.10/site-packages/numpy/_core/fromnumeric.py:3904: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/ansa/opt/anaconda3/lib/python3.10/site-packages/numpy/_core/fromnumeric.py:3904: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/ansa/opt/anaconda3/lib/python3.10/site-packages/numpy/_core/_methods.py:147: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /Users/ansa/opt/anaconda3/lib/python3.10/site-packages/numpy/_core/fromnumeric.py:3904: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/ansa/opt/anaconda3/lib/python3.10/site-packages/numpy/_core/_methods.py:147: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /Users/ansa/opt/anaconda3/lib/python3.10/site-packages/numpy/_core/_methods.py:147: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/Users/ansa/opt/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 463, in _process_worker
#     r = call_item()
#   File "/Users/ansa/opt/anaconda3/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 291, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "/Users/ansa/opt/anaconda3/lib/python3.10/site-packages/joblib/parallel.py", line 598, in __call__
#     return [func(*args, **kwargs)
#   File "/Users/ansa/opt/anaconda3/lib/python3.10/site-packages/joblib/parallel.py", line 598, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/var/folders/_d/f835sqm57dz2nyvw8sbgld300000gn/T/ipykernel_88373/2373149275.py", line 13, in mc_sim
#   File "/Users/ansa/opt/anaconda3/lib/python3.10/site-packages/scipy/interpolate/_rgi.py", line 412, in __call__
#     xi, xi_shape, ndim, nans, out_of_bounds = self._prepare_xi(xi)
#   File "/Users/ansa/opt/anaconda3/lib/python3.10/site-packages/scipy/interpolate/_rgi.py", line 469, in _prepare_xi
#     raise ValueError("One of the requested xi is out of bounds "
# ValueError: One of the requested xi is out of bounds in dimension 0
# """
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# File <timed exec>:1
#
# Cell In[15], line 38, in nvda_sim(data, num_sims)
#      30 T = (pd.to_datetime(row['expirationDate']) - pd.to_datetime('today')).days / 365  # time to expiration in years
#      31 #K_interp = np.clip(S[:, t-1], K_vals.min(), K_vals.max())
#      32 #sigma = interp_sigma(np.vstack((K_interp, np.full_like(K_interp, T_remaining))).T)
#      33
#      34 # Run Monte Carlo Simulation
#      35
#      36 #S_list = mc_sim2(steps, S0, r, K, T, dt, chunk_size, sigma)
# ---> 38 S_list = Parallel(n_jobs=num_cores)(
#      39     delayed(mc_sim)(steps, S0, r, K, T, dt, chunk_size)
#      40     for _ in range(num_cores)
#      41 )
#      42 S_array = np.concatenate(S_list, axis=0)
#      44 # Compute simulated payoff
#
# File ~/opt/anaconda3/lib/python3.10/site-packages/joblib/parallel.py:2007, in Parallel.__call__(self, iterable)
#    2001 # The first item from the output is blank, but it makes the interpreter
#    2002 # progress until it enters the Try/Except block of the generator and
#    2003 # reaches the first `yield` statement. This starts the asynchronous
#    2004 # dispatch of the tasks to the workers.
#    2005 next(output)
# -> 2007 return output if self.return_generator else list(output)
#
# File ~/opt/anaconda3/lib/python3.10/site-packages/joblib/parallel.py:1650, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1647     yield
#    1649     with self._backend.retrieval_context():
# -> 1650         yield from self._retrieve()
#    1652 except GeneratorExit:
#    1653     # The generator has been garbage collected before being fully
#    1654     # consumed. This aborts the remaining tasks if possible and warn
#    1655     # the user if necessary.
#    1656     self._exception = True
#
# File ~/opt/anaconda3/lib/python3.10/site-packages/joblib/parallel.py:1754, in Parallel._retrieve(self)
#    1747 while self._wait_retrieval():
#    1748
#    1749     # If the callback thread of a worker has signaled that its task
#    1750     # triggered an exception, or if the retrieval loop has raised an
#    1751     # exception (e.g. `GeneratorExit`), exit the loop and surface the
#    1752     # worker traceback.
#    1753     if self._aborting:
# -> 1754         self._raise_error_fast()
#    1755         break
#    1757     # If the next job is not ready for retrieval yet, we just wait for
#    1758     # async callbacks to progress.
#
# File ~/opt/anaconda3/lib/python3.10/site-packages/joblib/parallel.py:1789, in Parallel._raise_error_fast(self)
#    1785 # If this error job exists, immediately raise the error by
#    1786 # calling get_result. This job might not exists if abort has been
#    1787 # called directly or if the generator is gc'ed.
#    1788 if error_job is not None:
# -> 1789     error_job.get_result(self.timeout)
#
# File ~/opt/anaconda3/lib/python3.10/site-packages/joblib/parallel.py:745, in BatchCompletionCallBack.get_result(self, timeout)
#     739 backend = self.parallel._backend
#     741 if backend.supports_retrieve_callback:
#     742     # We assume that the result has already been retrieved by the
#     743     # callback thread, and is stored internally. It's just waiting to
#     744     # be returned.
# --> 745     return self._return_or_raise()
#     747 # For other backends, the main thread needs to run the retrieval step.
#     748 try:
#
# File ~/opt/anaconda3/lib/python3.10/site-packages/joblib/parallel.py:763, in BatchCompletionCallBack._return_or_raise(self)
#     761 try:
#     762     if self.status == TASK_ERROR:
# --> 763         raise self._result
#     764     return self._result
#     765 finally:
#
# ValueError: One of the requested xi is out of bounds in dimension 0

# %% [markdown]
# ### Black-Scholes

# %% [markdown]
# Make predictions with Black-Scholes

# %%
def black_scholes(S, K, T, r, sigma, type='call'):

# %%
predictions.to_csv("predicted_nvda_options_prices.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 predictions.to_csv("predicted_nvda_options_prices.csv", index=False)
#
# NameError: name 'predictions' is not defined
